# %%
import matplotlib.pyplot as plt
import math
def biseccion():
    print("Metodo de la biseccion")
    print("Suponiendo que la funcion sea e a la x-2")
    print("Siendo los intervalos [0.5,1.5]")
    xl=0.5
    xu=1.5
    fxl=(math.e**xl)-2
    fxu = (math.e**xu)-2
    xrgrafico=[]
    xlgrafico=[]
    xugrafico=[]
    xlgrafico.append(xl)
    xugrafico.append(xu)
    if(fxu*fxl<0):
        xr=(xl+xu)/2
        fxr = (math.e**xr)-2
        xrgrafico.append(xr)
        xlgrafico.append(xl)
        xugrafico.append(xu)
        c=0
        print("El valor de xr es "+ str(xr))
        er = 1
        while er > 0.001:
            if(fxu*fxr<0):
                xl=xr
                fxl = (math.e**xl)-2
                fxu = (math.e**xu)-2
                xr = (xl + xu) / 2
                fxr = (math.e**xr)-2
                er=(xr-xl)/xr
                xrgrafico.append(xr)
                xlgrafico.append(xl)
                xugrafico.append(xu)
                print("El valor de xr es "+ str(xr))
            if (fxl * fxr < 0):
                xu=xr
                fxl =(math.e**xl)-2
                fxu = (math.e**xu)-2
                xr = (xl + xu) / 2
                fxr = (math.e**xr)-2
                er = (xr - xl) / xr
                xrgrafico.append(xr)
                xlgrafico.append(xl)
                xugrafico.append(xu)
                print("El valor de xr es "+ str(xr))
            if (fxu*fxr>0 and fxl*fxr>0):
                print("No tiene raiz, fin del programa")
        plt.plot(xrgrafico)
        plt.plot(xlgrafico)
        plt.plot(xugrafico)
        plt.show
    else:
        print("No tiene raiz, fin del programa")
biseccion()

# %%
import matplotlib.pyplot as plt
import math
def biseccion():
    print("Metodo de la biseccion")
    print("Suponiendo nuestra funcion sea coseno de e a la x-2")
    print("Siendo los intervalos [0.5,1.5]")
    xl=0.5
    xu=1.5
    fxl=(math.cos((math.e**xl)-2))
    fxu = (math.cos((math.e**xu)-2))
    xrgrafico=[]
    xlgrafico=[]
    xugrafico=[]
    xlgrafico.append(xl)
    xugrafico.append(xu)
    if(fxu*fxl<0):
        xr=(xl+xu)/2
        fxr = (math.cos((math.e**xr)-2))
        xrgrafico.append(xr)
        xlgrafico.append(xl)
        xugrafico.append(xu)
        c=0
        print("El valor de xr es "+ str(xr))
        er = 1
        while er > (10**-5):
            if(fxu*fxr<0):
                xl=xr
                fxl = (math.cos((math.e**xl)-2))
                fxu = (math.cos((math.e**xu)-2))
                xr = (xl + xu) / 2
                fxr = (math.cos((math.e**xr)-2))
                er=(xr-xl)/xr
                xrgrafico.append(xr)
                xlgrafico.append(xl)
                xugrafico.append(xu)
                print("El valor de xr es "+ str(xr))
            if (fxl * fxr < 0):
                xu=xr
                fxl =(math.cos((math.e**xl)-2))
                fxu = (math.cos((math.e**xu)-2))
                xr = (xl + xu) / 2
                fxr = (math.cos((math.e**xr)-2))
                er = (xr - xl) / xr
                xrgrafico.append(xr)
                xlgrafico.append(xl)
                xugrafico.append(xu)
                print("El valor de xr es "+ str(xr))
            if (fxu*fxr>0 and fxl*fxr>0):
                print("No tiene raiz, fin del programa")
        plt.plot(xrgrafico)
        plt.plot(xlgrafico)
        plt.plot(xugrafico)
        plt.show
    else:
        print("No tiene raiz, fin del programa")
biseccion()

# %%
import matplotlib.pyplot as plt
import math
def fposicion():
    print("Metodo de la Falsa posicion")
    print("Suponiendo nuestra funcion sea e a la x-2")
    print("Siendo los intervalos [0.5,1.5]")
    xl=0.5
    xu=1.5
    fxl=(math.e**xl)-2
    fxu = (math.e**xu)-2
    xrgrafico=[]
    xlgrafico=[]
    xugrafico=[]
    xlgrafico.append(xl)
    xugrafico.append(xu)
    if(fxu*fxl<0):
        xr=(xu-((fxu*(xl-xu)/(fxl-fxu))))
        fxr = (math.e**xr)-2
        xrgrafico.append(xr)
        xlgrafico.append(xl)
        xugrafico.append(xu)
        c=0
        print("El valor de xr es "+ str(xr))
        er = 1
        while er > (10**-5):
            if(fxu*fxr<0):
                xl=xr
                fxl = (math.e**xl)-2
                fxu = (math.e**xu)-2
                xr = (xu-((fxu*(xl-xu)/(fxl-fxu))))
                fxr = (math.e**xr)-2
                er=(xr-xl)/xr
                xrgrafico.append(xr)
                xlgrafico.append(xl)
                xugrafico.append(xu)
                print("El valor de xr es "+ str(xr))
            if (fxl * fxr < 0):
                xu=xr
                fxl =(math.e**xl)-2
                fxu = (math.e**xu)-2
                xr = (xu-((fxu*(xl-xu)/(fxl-fxu))))
                fxr = (math.e**xr)-2
                er = (xr - xl) / xr
                xrgrafico.append(xr)
                xlgrafico.append(xl)
                xugrafico.append(xu)
                print("El valor de xr es "+ str(xr))
            if (fxu*fxr>0 and fxl*fxr>0):
                print("No tiene raiz, fin del programa")
        plt.plot(xrgrafico)
        plt.plot(xlgrafico)
        plt.plot(xugrafico)
        plt.show
    else:
        print("No tiene raiz, fin del programa")
fposicion()

# %%
import matplotlib.pyplot as plt
import math
def fposicion():
    print("Metodo de la Falsa posicion")
    print("Suponiendo nuestra funcion sea coseno de e a la x-2")
    print("Siendo los intervalos [0.5,1.5]")
    xl=0.5
    xu=1.5
    fxl=(math.cos((math.e**xl)-2))
    fxu = (math.cos((math.e**xu)-2))
    xrgrafico=[]
    xlgrafico=[]
    xugrafico=[]
    xlgrafico.append(xl)
    xugrafico.append(xu)
    if(fxu*fxl<0):
        xr=(xu-((fxu*(xl-xu)/(fxl-fxu))))
        fxr = (math.cos((math.e**xr)-2))
        xrgrafico.append(xr)
        xlgrafico.append(xl)
        xugrafico.append(xu)
        c=0
        print("El valor de xr es "+ str(xr))
        er = 1
        while er > (10**-5):
            if(fxu*fxr<0):
                xl=xr
                fxl = (math.cos((math.e**xl)-2))
                fxu = (math.cos((math.e**xu)-2))
                xr = (xu-((fxu*(xl-xu)/(fxl-fxu))))
                fxr = (math.cos((math.e**xr)-2))
                er=(xr-xl)/xr
                xrgrafico.append(xr)
                xlgrafico.append(xl)
                xugrafico.append(xu)
                print("El valor de xr es "+ str(xr))
            if (fxl * fxr < 0):
                xu=xr
                fxl =(math.cos((math.e**xl)-2))
                fxu = (math.cos((math.e**xu)-2))
                xr = (xu-((fxu*(xl-xu)/(fxl-fxu))))
                fxr = (math.cos((math.e**xr)-2))
                er = (xr - xl) / xr
                xrgrafico.append(xr)
                xlgrafico.append(xl)
                xugrafico.append(xu)
                print("El valor de xr es "+ str(xr))
            if (fxu*fxr>0 and fxl*fxr>0):
                print("No tiene raiz, fin del programa")
        plt.plot(xrgrafico)
        plt.plot(xlgrafico)
        plt.plot(xugrafico)
        plt.show
    else:
        print("No tiene raiz, fin del programa")
fposicion()
# Out:
# Metodo de la Falsa posicion
# Suponiendo nuestra funcion sea coseno de e a la x-2
# Siendo los intervalos [0.5,1.5]
# El valor de xr es 1.0430547821238234
# El valor de xr es 1.2525796575631347
# El valor de xr es 1.2730806624114597
# El valor de xr es 1.2727854236398422
# El valor de xr es 1.2727886311762442
